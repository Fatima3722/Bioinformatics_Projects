# %%
pip install chembl_webresource_client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 2.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Import Libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# **Search for Target protein**

# %%
# Target search for GPCRs
target = new_client.target
target_query = target.search('GPCRs')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#   cross_references      organism                                pref_name  \
# 0               []  Mus musculus               Free fatty acid receptor 2
# 1               []  Homo sapiens  Probable G-protein coupled receptor 148
# 2               []  Homo sapiens                 HM74 nicotinic acid GPCR
# 3               []  Homo sapiens  Probable G-protein coupled receptor 151
# 4               []  Homo sapiens                2-oxoglutarate receptor 1
# 5               []  Homo sapiens    G-protein coupled estrogen receptor 1
# 6               []  Homo sapiens                                VHL/GPER1
#
#    score  species_group_flag target_chembl_id  \
# 0    7.0               False    CHEMBL3309047
# 1    7.0               False    CHEMBL4523901
# 2    6.0               False       CHEMBL4421
# 3    6.0               False    CHEMBL3085617
# 4    5.0               False    CHEMBL2150840
# 5    4.0               False       CHEMBL5872
# 6    3.0               False    CHEMBL5169075
# ...

# %% [markdown]
# **Select and retrieve bioactivity data for HM74 nicotinic acid GPCR (second entry)**

# %%
selected_target = targets.target_chembl_id[2]
selected_target
# Out:
# 'CHEMBL4421'

# %% [markdown]
# Here, we will retrieve only bioactivity data for Homo sapiens	(CHEMBL4421) that are reported as IC50  values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None      2471798                  []
# 1        None             None      3413402                  []
# 2        None             None      3413403                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL988088  Activity at GPR109b assessed as inhibition of ...
# 1   CHEMBL1225926     Displacement of radioligand from human GPR109B
# 2   CHEMBL1225926     Displacement of radioligand from human GPR109B
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          F                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
#
#   target_organism          target_pref_name target_tax_id text_value  toid  \
# ...

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %% [markdown]
# **Copying files to Google Drive**

# %% [markdown]
# Firstly, we need to mount the Google Drive into Colab so that we can have access to our Google adrive from within Colab.

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# Next, we create a data folder in our Colab Notebooks folder on Google Drive.

# %%
mkdir "/content/gdrive/My Drive/Colab Notebooks/bioactivity data"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/Colab Notebooks/bioactivity data’: File exists

# %%
cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/bioactivity data"

# %%
 ls -l "/content/gdrive/My Drive/Colab Notebooks/bioactivity data"
# Out:
# total 4
# -rw------- 1 root root 2672 Jun  6 11:54 bioactivity_data.csv
# -rw------- 1 root root  271 Jun  3 09:24 bioactivity_preprocessed_data.csv

# %% [markdown]
# Let's see the CSV files that we have so far.

# %%
 ls
# Out:
# bioactivity_data.csv  gdrive/  sample_data/

# %% [markdown]
# Taking a glimpse of the bioactivity_data.csv file that we've just created.

# %%
# !head "/content/gdrive/My Drive/Colab Notebooks/bioactivity data/bioactivity_data.csv"
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ...

# %% [markdown]
# **Handling missing data**

# %% [markdown]
# If any compounds has missing value for the standard_value column then drop it

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None      2471798                  []
# 1        None             None      3413402                  []
# 2        None             None      3413403                  []
# 3        None             None      3413404                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL988088  Activity at GPR109b assessed as inhibition of ...
# 1   CHEMBL1225926     Displacement of radioligand from human GPR109B
# 2   CHEMBL1225926     Displacement of radioligand from human GPR109B
# 3   CHEMBL1225926     Displacement of radioligand from human GPR109B
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          F                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# ...

# %% [markdown]
# Apparently, for this dataset there is no missing data. But we can use the above code cell for bioactivity data of other target protein.

# %% [markdown]
# **Data pre-processing of the bioactivity data**

# %% [markdown]
# Labeling compounds as either being active, inactive or intermediate

# %% [markdown]
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be active while those greater than 10,000 nM will be considered to be inactive. As for those values in between 1,000 and 10,000 nM will be referred to as intermediate.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# **Iterate the molecule_chembl_id to a list**

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %% [markdown]
# **Iterate canonical_smiles to a list**

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %% [markdown]
# **Iterate standard_value to a list**

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %% [markdown]
# **Combine the 4 lists into a dataframe**

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#   molecule_chembl_id                      canonical_smiles bioactivity_class  \
# 0       CHEMBL278488         CC1(c2ccccc2)OC(C(=O)O)=CC1=O      intermediate
# 1      CHEMBL1223819         O=c1[nH]c(C(F)(F)F)nc2ncccc12          inactive
# 2      CHEMBL1224070  O=c1[nH]c(OCCCOc2ccccc2Cl)nc2ncccc12          inactive
# 3      CHEMBL1224147  O=c1[nH]c(COCCc2ccc(F)cc2)nc2ncccc12          inactive
#
#   standard_value
# 0         3000.0
# 1        50000.0
# 2        33000.0
# 3        50000.0

# %% [markdown]
# **Alternative method**

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]
df3
# Out:
#   molecule_chembl_id                      canonical_smiles standard_value
# 0       CHEMBL278488         CC1(c2ccccc2)OC(C(=O)O)=CC1=O         3000.0
# 1      CHEMBL1223819         O=c1[nH]c(C(F)(F)F)nc2ncccc12        50000.0
# 2      CHEMBL1224070  O=c1[nH]c(OCCCOc2ccccc2Cl)nc2ncccc12        33000.0
# 3      CHEMBL1224147  O=c1[nH]c(COCCc2ccc(F)cc2)nc2ncccc12        50000.0

# %%
pd.concat([df3,pd.Series(bioactivity_class)], axis=1)
# Out:
#   molecule_chembl_id                      canonical_smiles standard_value  \
# 0       CHEMBL278488         CC1(c2ccccc2)OC(C(=O)O)=CC1=O         3000.0
# 1      CHEMBL1223819         O=c1[nH]c(C(F)(F)F)nc2ncccc12        50000.0
# 2      CHEMBL1224070  O=c1[nH]c(OCCCOc2ccccc2Cl)nc2ncccc12        33000.0
# 3      CHEMBL1224147  O=c1[nH]c(COCCc2ccc(F)cc2)nc2ncccc12        50000.0
#
#               0
# 0  intermediate
# 1      inactive
# 2      inactive
# 3      inactive

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('bioactivity_preprocessed_data.csv', index=False)

# %%
! ls -l
# Out:
# total 16
# -rw-r--r-- 1 root root 2672 Jun  6 11:53 bioactivity_data.csv
# -rw-r--r-- 1 root root  271 Jun  6 11:55 bioactivity_preprocessed_data.csv
# drwx------ 6 root root 4096 Jun  6 11:54 gdrive
# drwxr-xr-x 1 root root 4096 Jun  4 21:29 sample_data

# %% [markdown]
# Let's copy to the Google Drive

# %%
! cp "/content/gdrive/My Drive/Colab Notebooks/bioactivity data"
# Out:
# cp: missing destination file operand after '/content/gdrive/My Drive/Colab Notebooks/bioactivity data'
# Try 'cp --help' for more information.

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/bioactivity data"
# Out:
# bioactivity_data.csv  bioactivity_preprocessed_data.csv
